# %% [markdown]
# # CLI Tutorial
#
# ---
#
# **GeoIPS Command Line Interface (CLI)**

# %% [markdown]
# **If you haven't installed Jupyter Notebook or aren't familiar with it, please follow the instructions linked [here](https://docs.jupyter.org/en/latest/install.html#jupyter-notebook-interface) before continuing.**

# %% [markdown]
# **If you don't have an environment already set up, please follow the steps 2 and 3 of the instructions linked [here](https://nrlmmd-geoips.github.io/geoips/getting-started/installing/index.html) based on the architecture of your machine.**
#
# You can quit following the instructions after you've activated your geoips environment via ``conda activate geoips``

# %% [markdown]
# ## Install GeoIPS and set up environment variables

# %%
GEOIPS_TESTDATA_DIR = !pwd
# %env GEOIPS_TESTDATA_DIR={GEOIPS_TESTDATA_DIR[0]}
# %env GEOIPS_OUTDIRS={GEOIPS_TESTDATA_DIR[0]}
# Out:
# env: GEOIPS_TESTDATA_DIR=/Users/erose/Downloads
# env: GEOIPS_OUTDIRS=/Users/erose/Downloads

# %%
# %%bash
#
# pip install geoips==1.16.1.post438.dev0
# Out:
# Requirement already satisfied: geoips==1.16.1.post438.dev0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (1.16.1.post438.dev0)
# Requirement already satisfied: alphashape>=1.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.3.1)
# Requirement already satisfied: astropy in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (7.1.0)
# Requirement already satisfied: cartopy>=0.23.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.24.1)
# Requirement already satisfied: colorama in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.4.6)
# Requirement already satisfied: ephem in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (4.2)
# Requirement already satisfied: h5py in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (3.14.0)
# Requirement already satisfied: hdf5plugin in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (5.1.0)
# Requirement already satisfied: isodate in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.7.2)
# Requirement already satisfied: jsonschema>4.18.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (4.24.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (3.10.3)
# Requirement already satisfied: netcdf4>1.7.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.7.2)
# Requirement already satisfied: numexpr in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2.11.0)
# Requirement already satisfied: numpy<2.3.0,>=2.2.4 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2.2.6)
# Requirement already satisfied: psutil in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (7.0.0)
# Requirement already satisfied: pyaml-env in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.2.2)
# Requirement already satisfied: pydantic>=2.10.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2.11.7)
# Requirement already satisfied: pygrib in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2.1.6)
# Requirement already satisfied: pyhdf in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.11.6)
# Requirement already satisfied: pyorbital in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.10.2)
# Requirement already satisfied: pypublicdecompwt in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2.8.1.6)
# Requirement already satisfied: pyresample in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.34.2)
# Requirement already satisfied: pyyaml in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (6.0.2)
# Requirement already satisfied: rasterio in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.4.3)
# Requirement already satisfied: referencing in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.36.2)
# Requirement already satisfied: rio-cogeo in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (5.4.2)
# Requirement already satisfied: satpy in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.57.0)
# Requirement already satisfied: scikit-image in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.25.2)
# Requirement already satisfied: scipy>1.2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (1.16.0)
# Requirement already satisfied: setuptools<70 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (69.5.1)
# Requirement already satisfied: tabulate in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (0.9.0)
# Requirement already satisfied: tqdm in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (4.67.1)
# Requirement already satisfied: xarray>=2025.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from geoips==1.16.1.post438.dev0) (2025.7.1)
# Requirement already satisfied: Click>=6.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (8.2.1)
# Requirement already satisfied: click-log>=0.3.2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (0.4.0)
# Requirement already satisfied: shapely>=1.4.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (2.1.1)
# Requirement already satisfied: trimesh>=3.9.8 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (4.7.0)
# Requirement already satisfied: networkx>=2.5 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (3.5)
# Requirement already satisfied: rtree>=0.9.7 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from alphashape>=1.3.1->geoips==1.16.1.post438.dev0) (1.4.0)
# Requirement already satisfied: packaging>=21 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from cartopy>=0.23.0->geoips==1.16.1.post438.dev0) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from cartopy>=0.23.0->geoips==1.16.1.post438.dev0) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from cartopy>=0.23.0->geoips==1.16.1.post438.dev0) (3.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from jsonschema>4.18.0->geoips==1.16.1.post438.dev0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from jsonschema>4.18.0->geoips==1.16.1.post438.dev0) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from jsonschema>4.18.0->geoips==1.16.1.post438.dev0) (0.26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (2.9.0.post0)
# Requirement already satisfied: cftime in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from netcdf4>1.7.0->geoips==1.16.1.post438.dev0) (1.6.4.post1)
# Requirement already satisfied: certifi in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from netcdf4>1.7.0->geoips==1.16.1.post438.dev0) (2025.7.9)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pydantic>=2.10.0->geoips==1.16.1.post438.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pydantic>=2.10.0->geoips==1.16.1.post438.dev0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pydantic>=2.10.0->geoips==1.16.1.post438.dev0) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pydantic>=2.10.0->geoips==1.16.1.post438.dev0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->geoips==1.16.1.post438.dev0) (1.17.0)
# Requirement already satisfied: pandas>=2.2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from xarray>=2025.3.1->geoips==1.16.1.post438.dev0) (2.3.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2025.3.1->geoips==1.16.1.post438.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2025.3.1->geoips==1.16.1.post438.dev0) (2025.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from astropy->geoips==1.16.1.post438.dev0) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from astropy->geoips==1.16.1.post438.dev0) (0.2025.7.7.0.39.39)
# Requirement already satisfied: defusedxml in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyorbital->geoips==1.16.1.post438.dev0) (0.7.1)
# Requirement already satisfied: requests in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyorbital->geoips==1.16.1.post438.dev0) (2.32.4)
# Requirement already satisfied: configobj in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyresample->geoips==1.16.1.post438.dev0) (5.0.9)
# Requirement already satisfied: pykdtree>=1.3.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyresample->geoips==1.16.1.post438.dev0) (1.4.2)
# Requirement already satisfied: donfig in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyresample->geoips==1.16.1.post438.dev0) (0.8.1.post1)
# Requirement already satisfied: platformdirs in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from pyresample->geoips==1.16.1.post438.dev0) (4.3.8)
# Requirement already satisfied: affine in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from rasterio->geoips==1.16.1.post438.dev0) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from rasterio->geoips==1.16.1.post438.dev0) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from rasterio->geoips==1.16.1.post438.dev0) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from requests->pyorbital->geoips==1.16.1.post438.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from requests->pyorbital->geoips==1.16.1.post438.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from requests->pyorbital->geoips==1.16.1.post438.dev0) (2.5.0)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from rio-cogeo->geoips==1.16.1.post438.dev0) (6.2.0)
# Requirement already satisfied: dask>=0.17.1 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (2025.5.1)
# Requirement already satisfied: pooch in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from satpy->geoips==1.16.1.post438.dev0) (1.8.2)
# Requirement already satisfied: trollimage>=1.24 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from satpy->geoips==1.16.1.post438.dev0) (1.26.0)
# Requirement already satisfied: trollsift in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from satpy->geoips==1.16.1.post438.dev0) (0.5.3)
# Requirement already satisfied: zarr in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from satpy->geoips==1.16.1.post438.dev0) (3.0.10)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (2025.5.1)
# Requirement already satisfied: partd>=1.4.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (3.23.0)
# Requirement already satisfied: locket in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from partd>=1.4.0->dask>=0.17.1->dask[array]>=0.17.1->satpy->geoips==1.16.1.post438.dev0) (1.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from scikit-image->geoips==1.16.1.post438.dev0) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from scikit-image->geoips==1.16.1.post438.dev0) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from scikit-image->geoips==1.16.1.post438.dev0) (0.4)
# Requirement already satisfied: numcodecs>=0.14 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->satpy->geoips==1.16.1.post438.dev0) (0.16.1)
# Requirement already satisfied: crc32c>=2.7 in /Users/erose/anaconda3/envs/geoips/lib/python3.11/site-packages (from numcodecs[crc32c]>=0.14->zarr->satpy->geoips==1.16.1.post438.dev0) (2.7.1)

# %%
# !echo $GEOIPS_PACKAGES_DIR

# %% [markdown]
# ## Interrogation & Execution

# %% [markdown]
# The GeoIPS CLI ([documentation](https://nrlmmd-geoips.github.io/geoips/concepts/functionality/command-line/index.html#geoips)) is a high-level tool which improves the accessibility, flexibility, and control of GeoIPS.
#
# It’s composed of two parts:
#
# ### Interrogation
# - Search through GeoIPS and its corresponding plugin packages to see what exists.
# - List GeoIPS artifacts (packages, plugins, interfaces, scripts, datasets, …)
# - Description of artifacts
#
# ### Execution
# - Run a GeoIPS processing workflow (procflow)
# - Validate plugins
# - Run GeoIPS tests
# - Configuration of GeoIPS and its plugin packages

# %% [markdown]
# ## Command: geoips tree

# %% [markdown]
# Expose all CLI commands in a tree-like fashion.
#
# General Syntax:
# ```
# geoips tree <opt_args>
# ```

# %%
# %%bash
#
# geoips tree --color
# Out:
# geoips
#     geoips config
#         geoips config create-registries
#         geoips config delete-registries
#         geoips config install
#         geoips config install-github
#     geoips describe
#         geoips describe algorithms
#         geoips describe colormappers
#         geoips describe coverage-checkers
#         geoips describe databases
#         geoips describe feature-annotators
#         geoips describe filename-formatters
#         geoips describe gridline-annotators
#         geoips describe interpolators
#         geoips describe output-checkers
#         geoips describe output-formatters
#         geoips describe package
#         geoips describe procflows
#         geoips describe product-defaults
#         geoips describe products
#         geoips describe readers
#         geoips describe sector-adjusters
#         geoips describe sector-metadata-generators
#         geoips describe sector-spec-generators
#         geoips describe sectors
#         geoips describe title-formatters
#         geoips describe workflows
#     geoips list
#         geoips list algorithms
#         geoips list colormappers
#         geoips list coverage-checkers
#         geoips list databases
#         geoips list feature-annotators
#         geoips list filename-formatters
#         geoips list gridline-annotators
#         geoips list interfaces
#         geoips list interpolators
#         geoips list output-checkers
#         geoips list output-formatters
#         geoips list packages
#         geoips list plugins
#         geoips list procflows
#         geoips list product-defaults
#         geoips list products
#         geoips list readers
#         geoips list registries
#         geoips list scripts
#         geoips list sector-adjusters
#         geoips list sector-metadata-generators
#         geoips list sector-spec-generators
#         geoips list sectors
#         geoips list source-names
#         geoips list test-datasets
#         geoips list title-formatters
#         geoips list unit-tests
#         geoips list workflows
#     geoips run
#         geoips run config_based
#         geoips run data_fusion
#         geoips run order_based
#         geoips run single_source
#     geoips test
#         geoips test linting
#         geoips test script
#         geoips test sector
#     geoips tree
#     geoips validate
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## CLI Help Messages

# %% [markdown]
# For any command ran via the CLI, you can request a help message.
#
# To do so, all you have to do is:
# ```
# geoips <command> <sub-command> <...> -h
# ```
#
# This will output help text for the command being ran.
# Useful for a reminder or for new users of the CLI.
#
# For example:

# %%
# %%bash
#
# geoips -h

# %%
# %%bash
#
# geoips describe -h

# %% [markdown]
# ## CLI Aliases

# %% [markdown]
# You'll see from the previous commands that GeoIPS CLI has a variety of sub-commands. These commands are somewhat verbose; to improve ease of use, aliases for each command can be used to execute in shorthand style.

# %%
# %%bash
#
# geoips describe reader abi_netcdf
# geoips desc rdr abi_netcdf
#
# geoips list product-defaults
# geoips ls pdefs
#
# geoips describe algorithm family xarray_dict_to_xarray
# geoips desc alg fam xarray_dict_to_xarray

# %% [markdown]
# ## Ensure your package is installed correctly

# %% [markdown]
# Use the CLI to check whether your package is installed correctly.
#
# If you just have **geoips** and **geoips_clavrx** installed, you should see two rows that correspond to those packages. If any additional GeoIPS packages are installed, you should see those as well.
#
# General Syntax:
# ```
# geoips list packages
# ```

# %%
# %%bash
#
# geoips list packages

# %% [markdown]
# ## Command: geoips list

# %% [markdown]
# List all reader plugins from GeoIPS & installed plugin packages.
#
# If just **geoips** and **geoips_clavrx** are installed, you should see reader plugins contained in both of those packages.
#
# General Syntax:
# ```
# geoips list <interface_name>
# ```

# %%
# %%bash
#
# geoips list readers

# %% [markdown]
# ## List plugins from a specific plugin package

# %% [markdown]
# List available plugins of a particular type from a specific plugin package.
#
# General Syntax:
# ```
# geoips list <interface_name> -p <package_name>
# ```

# %%
# %%bash
#
# # if geoips_clavrx is installed, you can run the command below. Same goes for any other geoips-based package
# geoips list readers -p geoips_clavrx
# # Otherwise, for clarity's sake, you can list reader plugins from a specific package via
# # geoips list readers -p <installed_package_name>

# %% [markdown]
# ## Command: geoips describe

# %% [markdown]
# Display additional information about a particular plugin.
#
# General Syntax:
# ```
# geoips describe <interface_name> <plugin_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips describe reader clavrx_hdf4
# # Otherwise, run a command similar to what is shown below
# # geoips describe reader <name_of_reader_in_installed_package>

# %% [markdown]
# ## Command: geoips list products

# %% [markdown]
# List the products that GeoIPS can produce using a particular plugin package.
#
# General Syntax:
# ```
# geoips list <interface_name> -p <package_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips list products -p geoips_clavrx
# # Otherwise, run a command similar to what is shown below
# # geoips list products -p <installed_package_name>

# %% [markdown]
# ## Command: geoips describe product

# %% [markdown]
# Display additional information about a particular product plugin.
#
# Running this command describes ‘Cloud-Fraction’, including:
# - What type of plugin it is
# - Where it comes from
# - What source supports this product
#
# General Syntax:
# ```
# geoips describe <interface_name> <source_name>.<plugin_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips describe product clavrx.Cloud-Fraction
# # Otherwise, run a command similar to what is shown below
# # geoips deescribe product <name_of_product_in_installed_package>

# %% [markdown]
# ## Command: geoips list scripts

# %% [markdown]
# Each package contains test scripts to test its various products.
#
# Get a list of test scripts from a particular plugin package.
#
# These are example scripts, mostly used for integration testing.
#
# Useful as templates for your own scripts.
#
# General Syntax:
# ```
# geoips list scripts -p <package_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips list scripts -p geoips_clavrx
# # Otherwise, run a command similar to what is shown below
# # geoips list scripts -p <installed_package_name>

# %% [markdown]
# ## Command: geoips config install

# %% [markdown]
# Install GeoIPS’ test datasets.
#
# Running this command downloads and extracts test datasets from our nextcloud storage server.
# These test datasets are needed for various integration tests across GeoIPS and its plugin packages.
#
# General Syntax:
# ```
# geoips config install <test_dataset_name> <test_dataset_name2> ...
# ```
#
# To view what datasets are available for install, run:
# ```
# geoips list test-datasets
# ```

# %%
# %%bash
#
# geoips config install test_data_abi

# %% [markdown]
# ## Command: geoips run

# %% [markdown]
# GeoIPS is run by calling `geoips run`.
#
# For repeatability, this can be put into a bash script (e.g. `abi.Cloud-Fraction.imagery_clean.sh`).
#
# General Syntax:
# ```
# geoips run <procflow_name> <procflow_args>
# ```
#
# For a listing of scripts available in core GeoIPS, see [here](https://github.com/NRLMMD-GEOIPS/geoips/tree/main/tests/scripts).
#
# Note that you'll need to have the corresponding test data installed for these scripts to work.

# %%
# %%bash
#
# geoips run single_source \
# $GEOIPS_TESTDATA_DIR/test_data_abi/data/goes16_20200918_1950/*.nc \
#    --reader_name abi_netcdf \
#    --product_name Infrared \
#    --output_formatter imagery_clean \
#    --sector_list goes_east
#
# # Feel free to replace the contents of this code section with a test script that
# # native GeoIPS supports
# Out:
# 10_141123    log_setup.py:162  INTERACTIVE:
#
#
# Starting single_source procflow...
#
#
# 10_141123    log_setup.py:162  INTERACTIVE:
#
#
# Running on filenames: ['/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C01_G16_s20202621950205_e20202621959513_c20202621959567.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C02_G16_s20202621950205_e20202621959513_c20202621959546.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C03_G16_s20202621950205_e20202621959513_c20202621959570.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C04_G16_s20202621950205_e20202621959513_c20202621959534.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C05_G16_s20202621950205_e20202621959513_c20202621959562.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C06_G16_s20202621950205_e20202621959518_c20202621959556.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C07_G16_s20202621950205_e20202621959524_c20202621959577.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C08_G16_s20202621950205_e20202621959513_c20202621959574.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C09_G16_s20202621950205_e20202621959518_c20202621959588.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C10_G16_s20202621950205_e20202621959524_c20202621959578.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C11_G16_s20202621950205_e20202621959513_c20202621959583.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C12_G16_s20202621950205_e20202621959518_c20202621959574.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C13_G16_s20202621950205_e20202621959525_c20202622000005.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C14_G16_s20202621950205_e20202621959513_c20202622000009.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C15_G16_s20202621950205_e20202621959518_c20202621959594.nc', '/Users/erose/Downloads/test_data_abi/data/goes16_20200918_1950/OR_ABI-L1b-RadF-M6C16_G16_s20202621950205_e20202621959524_c20202622000001.nc']
#
#
# 10_141123    log_setup.py:162  INTERACTIVE: Reading metadata from dataset with reader 'abi_netcdf'...
# 10_141124    log_setup.py:162  INTERACTIVE: Getting all area defs from command line args:
# 10_141124    log_setup.py:162  INTERACTIVE:   sector_list: ['goes_east']
# 10_141124    log_setup.py:162  INTERACTIVE:   tcdb_sector_list: None
# 10_141124    log_setup.py:162  INTERACTIVE:   tcdb: False
# 10_141124    log_setup.py:162  INTERACTIVE:   trackfile_sector_list: None
# 10_141124    log_setup.py:162  INTERACTIVE:   trackfiles: None
# 10_141124    log_setup.py:162  INTERACTIVE:   trackfile_parser: None
# 10_141124    log_setup.py:162  INTERACTIVE:   tc_spec_template: None
# 10_141124    log_setup.py:162  INTERACTIVE: Reading full dataset with reader 'abi_netcdf'...
# 10_141127    log_setup.py:162  INTERACTIVE: Done with geolocation for Full-Disk
# 10_141131    log_setup.py:162  INTERACTIVE: Sectoring xarrays, variables ['B14BT']...
# 10_141132    log_setup.py:162  INTERACTIVE: Producing sectored outputs...
# 10_141132    log_setup.py:162  INTERACTIVE: Applying algorithms and interpolation...
# 10_141132    log_setup.py:162  INTERACTIVE: Resectoring xarrays without padding...
# 10_141133    log_setup.py:162  INTERACTIVE:   Applying interpolators...
# 10_141133    log_setup.py:162  INTERACTIVE:   Interpolating data with interpolator 'interp_nearest' args '{'varlist': ['B14BT']}'...
# 10_141136    log_setup.py:162  INTERACTIVE:   Applying algorithms after interpolators...
# 10_141136    log_setup.py:162  INTERACTIVE:   Applying 'list_numpy_to_numpy' family algorithm 'single_channel' to data...
# 10_141136    log_setup.py:162  INTERACTIVE:   Setting metadata on final xarray...
# 10_141136    log_setup.py:162  INTERACTIVE: Required coverage 10 for product Infrared, actual coverage 45.56125
# 10_141136 single_source.py:825  WARNING: REMOVING UNSUPPORTED <geoips.interfaces.base.OutputFormattersPlugin object at 0x11ed63c90> key output_dict
# 10_141136    log_setup.py:162  INTERACTIVE: Producing product 'Infrared' final outputs as type 'imagery_clean'...
# 10_141136    log_setup.py:162  INTERACTIVE:   Producing 'image' family final outputs 'imagery_clean'...
# 10_141137 duplicate_files.py:64   WARNING: SKIPPING DUPLICATE REMOVAL no geoips_fname_remove_duplicates defined
# 10_141137    log_setup.py:162  INTERACTIVE:
#
#
# Processing complete! Checking outputs...
#
#
# 10_141137    log_setup.py:162  INTERACTIVE:
#
#
# The following products were produced from procflow single_source.py
#
#
# 10_141137    log_setup.py:162  INTERACTIVE:     SINGLESOURCESUCCESS ${GEOIPS_OUTDIRS}/preprocessed/annotated_imagery/Global-x-GOES-East/x-x-x/Infrared/abi/20200918.195020.goes-16.abi.Infrared.goes_east.45p56.noaa.10p0.png
# 10_141137    log_setup.py:162  INTERACTIVE: READER_NAME: abi_netcdf
# 10_141137    log_setup.py:162  INTERACTIVE: PRODUCT_NAME: Infrared
# 10_141137    log_setup.py:162  INTERACTIVE: NUM_PRODUCTS: 1
# 10_141137    log_setup.py:162  INTERACTIVE: NUM_DELETED_PRODUCTS: 0
# 10_141137    log_setup.py:162  INTERACTIVE: Completed geoips PROCFLOW single_source processing, done!
# 10_141137    log_setup.py:162  INTERACTIVE: Total time: 0:00:14.197274
# 10_141137    log_setup.py:162  INTERACTIVE: Return value: 0

# %% [markdown]
# ## Command: geoips test sector

# %% [markdown]
# Produce a ‘test sector image’.
#
# Running this command produces a test sector image from the ‘canada’ sector plugin.
# This is an easy method to view what geospatial domain a sector you’ve created captures.
#
# General Syntax:
# ```
# geoips test sector <sector_name>
# ```

# %%
# %%bash
#
# geoips test sector canada

# %% [markdown]
# ## Command: geoips config create/delete registries

# %% [markdown]
# Create or delete plugin registries.
#
# Running either of these commands will create or delete plugin registries.
# These files are needed for GeoIPS to be able to dynamically locate a plugin at runtime.
#
# General Syntax:
# ```
# geoips config create-registries -n <namespace> -p <package_names> -s <save_type>
# geoips config delete-registries -n <namespace> -p <package_names>
# ```
#
# Note: Registries are automatically created if a plugin is missing at runtime.
# You can disable this by adding the following line in your `.bashrc`:
# ```
# export GEOIPS_REBUILD_REGISTRIES="False"
# ```

# %%
# %%bash
#
# geoips config create-registries
# # geoips config delete-registries
