# %% [markdown]
# # CLI Tutorial
#
# ---
#
# **GeoIPS Command Line Interface (CLI)**

# %% [markdown]
# **If you haven't installed Jupyter Notebook or aren't familiar with it, please follow the instructions linked [here](https://docs.jupyter.org/en/latest/install.html#jupyter-notebook-interface) before continuing.**

# %% [markdown]
# **If you don't have an environment already set up, please follow the steps 2 and 3 of the instructions linked [here](https://nrlmmd-geoips.github.io/geoips/getting-started/installing/index.html) based on the architecture of your machine.**
#
# You can quit following the instructions after you've activated your geoips environment via ``conda activate geoips``

# %% [markdown]
# ## System requirements
#
# - **CPU:** 1 CPU
# - **RAM:** 40GB as the notebook is written, but could use more if modified.
#   Reading the entire full-disk ABI image can take up to 100GB.
# - **Disk Space:** 3GB storage space.
#
# ***To see the default storage location for your system, run the cell below.***
# To change the default location, change the value of `tmp_root` in the following cell.

# %%
import tempfile
from pathlib import Path

# Set this to a different path if you would like to use a different location
# `tempfile.gettempdir()` returns a different location on different OS.

# tmp_root = "/use/this/path/instead"
tmp_root = Path(tempfile.gettempdir()) / "geoips_tutorial_tempdirs"

print(f"Notebook temporary storage path: {tmp_root}")
# Out:
# Notebook temporary storage path: /tmp/geoips_tutorial_tempdirs

# %% [markdown]
# ## Important notes
# This notebook downloads approximately 2GB of data and produces another 1GB. It
# is stored in the location reported by running the next cell.
#
# This notebook makes an attempt at cleaning up after itself, but it is
# recommended that, when done using this notebook, you check to be sure that the
# directory reported by the next cell has been deleted.
#
# ## Setting up your Environment
#
# **If you don't have an environment already set up, please follow the steps 2 and 3 of the instructions linked [here](https://nrlmmd-geoips.github.io/geoips/getting-started/installing/index.html) based on the architecture of your machine.**
#
# You can quit following the instructions after you've activated your geoips environment via <br />
# ``conda activate geoips``.
#
# Run the cell below to set up your environment. This will initialize a session-specific <br />
# storage directory, add it to the global notebook environment, and add a hook that attempts <br />
# to clean up the temporary storage when the notebook is closed.
#
# ❗
# ***Important:*** While this notebook makes an effort to clean up after itself, if you <br />
# are running this notebook on your own system, ***it is advisable tomanually delete the <br />
# temporary directory reported above when you are done using the notebook.***

# %%
import dotenv
from IPython import get_ipython
import os

from utils import notebook_environment

# Sets up the environment and sets a global variable named `temp_dir`
notebook_environment.setup(tmp_root)

with open("./.env", "w") as env_file:
    env_file.writelines(
        [
            f"GEOIPS_TESTDATA_DIR={get_ipython().user_ns['temp_dir']}/test_data\n",
            f"GEOIPS_OUTDIRS={get_ipython().user_ns['temp_dir']}/outdirs\n",
            f"GEOIPS_PACKAGES_DIR={get_ipython().user_ns['temp_dir']}\n",
            f"GEOIPS_REBUILD_REGISTRIES=True",
            f"MY_PKG_DIR={get_ipython().user_ns['temp_dir']}/cool_plugins\n",
            "MY_PKG_NAME=cool_plugins"
        ],
    )

dotenv.load_dotenv("./.env", override=True)

if not os.path.exists(os.environ["GEOIPS_TESTDATA_DIR"]):
    os.makedirs(os.environ["GEOIPS_TESTDATA_DIR"])
if not os.path.exists(os.environ["GEOIPS_OUTDIRS"]):
    os.makedirs(os.environ["GEOIPS_OUTDIRS"])
# Out:
# Tutorial Temporary Storage Dir: /tmp/geoips_tutorial_tempdirs
# Cleaning all previous tutorial temp dirs...
# Setting up cleanup hook for current session temp dir...
# Making `temp_dir` variable available globally...
# Session Temporary Directory: /tmp/geoips_tutorial_tempdirs/geoips_tutorial_tmp_58db041b6e7c4d5c98890cd6ad2e7736

# %%
# %%bash
#
# pip install --force-reinstall --pre geoips
# pip install --upgrade geoips_clavrx

# %% [markdown]
# ## Interrogation & Execution

# %% [markdown]
# The GeoIPS CLI ([documentation](https://nrlmmd-geoips.github.io/geoips/concepts/functionality/command-line/index.html#geoips)) is a high-level tool which improves the accessibility, flexibility, and control of GeoIPS.
#
# It’s composed of two parts:
#
# ### Interrogation
# - Search through GeoIPS and its corresponding plugin packages to see what exists.
# - List GeoIPS artifacts (packages, plugins, interfaces, scripts, datasets, …)
# - Description of artifacts
#
# ### Execution
# - Run a GeoIPS processing workflow (procflow)
# - Validate plugins
# - Run GeoIPS tests
# - Configuration of GeoIPS and its plugin packages

# %% [markdown]
# ## Command: geoips tree

# %% [markdown]
# Expose all CLI commands in a tree-like fashion.
#
# General Syntax:
# ```
# geoips tree <opt_args>
# ```

# %%
# %%bash
#
# geoips tree --color
# Out:
# geoips
#     geoips config
#         geoips config create-registries
#         geoips config delete-registries
#         geoips config install
#         geoips config install-github
#     geoips describe
#         geoips describe algorithms
#         geoips describe colormappers
#         geoips describe coverage-checkers
#         geoips describe databases
#         geoips describe feature-annotators
#         geoips describe filename-formatters
#         geoips describe gridline-annotators
#         geoips describe interpolators
#         geoips describe output-checkers
#         geoips describe output-formatters
#         geoips describe package
#         geoips describe procflows
#         geoips describe product-defaults
#         geoips describe products
#         geoips describe readers
#         geoips describe sector-adjusters
#         geoips describe sector-metadata-generators
#         geoips describe sector-spec-generators
#         geoips describe sectors
#         geoips describe title-formatters
#         geoips describe workflows
#     geoips list
#         geoips list algorithms
#         geoips list colormappers
#         geoips list coverage-checkers
#         geoips list databases
#         geoips list feature-annotators
#         geoips list filename-formatters
#         geoips list gridline-annotators
#         geoips list interfaces
#         geoips list interpolators
#         geoips list output-checkers
#         geoips list output-formatters
#         geoips list packages
#         geoips list plugins
#         geoips list procflows
#         geoips list product-defaults
#         geoips list products
#         geoips list readers
#         geoips list registries
#         geoips list scripts
#         geoips list sector-adjusters
#         geoips list sector-metadata-generators
#         geoips list sector-spec-generators
#         geoips list sectors
#         geoips list source-names
#         geoips list test-datasets
#         geoips list title-formatters
#         geoips list unit-tests
#         geoips list workflows
#     geoips run
#         geoips run config_based
#         geoips run data_fusion
#         geoips run order_based
#         geoips run single_source
#     geoips test
#         geoips test linting
#         geoips test script
#         geoips test sector
#     geoips tree
#     geoips validate
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## CLI Help Messages

# %% [markdown]
# For any command ran via the CLI, you can request a help message.
#
# To do so, all you have to do is:
# ```
# geoips <command> <sub-command> <...> -h
# ```
#
# This will output help text for the command being ran.
# Useful for a reminder or for new users of the CLI.
#
# For example:

# %%
# %%bash
#
# geoips -h
# Out:
# usage: geoips [-h] [-log {debug,info,warning,interactive,error,critical}]
#               [--warnings {default,error,ignore,always,module,once}]
#               {config,cfg,describe,desc,list,ls,run,test,tree,validate,val}
#               ...
#
# positional arguments:
#   {config,cfg,describe,desc,list,ls,run,test,tree,validate,val}
#                         geoips instructions.
#     config (cfg)        Various configuration-based commands for setting up your geoips environment.
#                         Currently supports `geoips config install ...` and
#                         `geoips config <create/delete-registries>` commands.
#     describe (desc)     Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     list (ls)           List off available GeoIPS artifacts provided further commands. Current artifacts
#                         available for listing are: ["algorithms", "colormappers", "coverage_checkers",
#                         "databases",
#                         "filename_formatters", "interpolators", "output_checkers", "output_formatters",
#                         "procflows", "readers", "sector_adjusters", "sector_metadata_generators",
#                         "sector_spec_generators", "title_formatters", "feature_annotators",
#                         "gridline_annotators", "product_defaults", "products", "sectors", "interfaces",
#                         "packages", "plugins", "scripts", "test-datasets", "unit-tests"].
#     run                 Run a specified geoips process workflow (procflow) plugin. See
#                         'geoips run single_source' or 'geoips run data_fusion' for more information of
#                         what arguments to provide.
#     test                Run tests implemented in GeoIPS or a separate GeoIPS Package. This could be
#                         running a set of linters on a specific package, running a certain integration or
#                         normal test script, or running unit tests. Current options are ["linting",
#                         "script", "unit-test"].
#     tree                Print a tree of all of the available GeoIPS CLI commands. This will display every
#                         command in a top-down tree which gives a visual structure of how the CLI can be
#                         ran. <--max-depth> must be greater than or equal to 0, where depth denotes the
#                         level of the command you'd like to display. Ie. <0> geoips <1> list <2> scripts.
#     validate (val)      Validate a GeoIPS Plugin found at <file_path>. While this is done under the hood
#                         via GeoIPS, this is an easy way to test whether or not the plugin you are
#                         developing is valid. If the <file_path> you're trying to validate is a
#                         multi-document YAML file, you'll also need to provide the name of the plugin
#                         within that file for this command to work.
#
# options:
#   --warnings {default,error,ignore,always,module,once}
#                         Set the warning level for the CLI. See the warnings module documentation for more information: https://docs.python.org/3/library/warnings.html#warning-filter
#   -h, --help            show this help message and exit
#   -log {debug,info,warning,interactive,error,critical}, --log-level {debug,info,warning,interactive,error,critical}
#                         Log level to output when using the CLI.

# %%
# %%bash
#
# geoips describe -h
# Out:
# usage: To use, type `geoips describe <interface_name> <sub-cmd> ...`.
#
# Retrieve information about a GeoIPS artifact. For this command, an artifact is one
# of ['interface', 'plugin', 'family']. To get more information on how to
# retrieve these artifacts, see below.
#
# * Interface:
#     * Command Signature:
#         * `geoips describe <interface_name>`
#     * Artifact Listing:
#         * `geoips list interfaces`
#     * output_info:
#         * Absolute Path
#         * Docstring
#         * Interface Name
#         * Interface Type
#         * Supported Families
#
# * Plugin:
#     * Command Signature:
#         * `geoips describe <interface_name> <plugin_name>`
#     * Artifact Listing:
#         * `geoips list plugins <-p> <package-name>`
#     * Output Info:
#         * Docstring
#         * Family Name
#         * GeoIPS Package
#         * Interface Name
#         * Plugin Type
#         * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#         * Relative Path
#
# * Family:
#     * Command Signature:
#         * `geoips describe <interface_name> family <family_name>`
#     * Artifact Listing:
#         * `geoips list interfaces --columns interface supported_families`
#     * Output Info:
#         * Docstring
#         * Family Name
#         * Family Path
#         * Interface Name
#         * Interface Type
#         * Required Arguments / Schema
#
# positional arguments:
#   {algorithms,alg,algs,algorithm,colormappers,cmap,cmaps,colormapper,coverage-checkers,cchk,cchks,coverage-checker,databases,db,dbs,database,feature-annotators,fann,fanns,feature-annotator,filename-formatters,ffmt,ffmts,filename-formatter,gridline-annotators,gann,ganns,gridline-annotator,interpolators,interp,interps,interpolator,output-checkers,ochk,ochks,output-checker,output-formatters,ofmt,ofmts,output-formatter,package,pkg,procflows,pfl,pfls,procflow,product-defaults,pdef,pdefs,prod-def,prod-defs,product-default,products,prod,prods,product,readers,rdr,rdrs,reader,sector-adjusters,sadj,sadjs,sector-adjuster,sector-metadata-generators,smgen,smgens,sector-metadata-generator,sector-spec-generators,ssgen,ssgens,sector-spec-generator,sectors,sec,secs,sector,title-formatters,tfmt,tfmts,title-formatter,workflows,wf,wfs,workflow}
#                         describe instructions.
#     algorithms (alg, algs, algorithm)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     colormappers (cmap, cmaps, colormapper)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     coverage-checkers (cchk, cchks, coverage-checker)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     databases (db, dbs, database)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     feature-annotators (fann, fanns, feature-annotator)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     filename-formatters (ffmt, ffmts, filename-formatter)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     gridline-annotators (gann, ganns, gridline-annotator)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     interpolators (interp, interps, interpolator)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     output-checkers (ochk, ochks, output-checker)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     output-formatters (ofmt, ofmts, output-formatter)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     package (pkg)       Retrieve the appropriate GeoIPS Package alongside descriptive information of
#                         that package. See output_info for each datum provided when this command is
#                         called. For a listing of available GeoIPS packages, run:
#                         `geoips list packages`.
#     procflows (pfl, pfls, procflow)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     product-defaults (pdef, pdefs, prod-def, prod-defs, product-default)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     products (prod, prods, product)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     readers (rdr, rdrs, reader)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     sector-adjusters (sadj, sadjs, sector-adjuster)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     sector-metadata-generators (smgen, smgens, sector-metadata-generator)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     sector-spec-generators (ssgen, ssgens, sector-spec-generator)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     sectors (sec, secs, sector)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     title-formatters (tfmt, tfmts, title-formatter)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#     workflows (wf, wfs, workflow)
#                         Retrieve information about a GeoIPS artifact. For this command, an artifact is one
#                         of ['interface', 'plugin', 'family']. To get more information on how to
#                         retrieve these artifacts, see below.
#
#                         * Interface:
#                             * Command Signature:
#                                 * `geoips describe <interface_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces`
#                             * output_info:
#                                 * Absolute Path
#                                 * Docstring
#                                 * Interface Name
#                                 * Interface Type
#                                 * Supported Families
#
#                         * Plugin:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> <plugin_name>`
#                             * Artifact Listing:
#                                 * `geoips list plugins <-p> <package-name>`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * GeoIPS Package
#                                 * Interface Name
#                                 * Plugin Type
#                                 * call_sig / source_names / Product Defaults (dependent on Plugin Type)
#                                 * Relative Path
#
#                         * Family:
#                             * Command Signature:
#                                 * `geoips describe <interface_name> family <family_name>`
#                             * Artifact Listing:
#                                 * `geoips list interfaces --columns interface supported_families`
#                             * Output Info:
#                                 * Docstring
#                                 * Family Name
#                                 * Family Path
#                                 * Interface Name
#                                 * Interface Type
#                                 * Required Arguments / Schema
#
# options:
#   --warnings {default,error,ignore,always,module,once}
#                         Set the warning level for the CLI. See the warnings module documentation for more information: https://docs.python.org/3/library/warnings.html#warning-filter
#   -h, --help            show this help message and exit
#   -log {debug,info,warning,interactive,error,critical}, --log-level {debug,info,warning,interactive,error,critical}
#                         Log level to output when using the CLI.

# %% [markdown]
# ## CLI Aliases

# %% [markdown]
# You'll see from the previous commands that GeoIPS CLI has a variety of sub-commands. These commands are somewhat verbose; to improve ease of use, aliases for each command can be used to execute in shorthand style.

# %%
# %%bash
#
# geoips describe reader abi_netcdf
# geoips desc rdr abi_netcdf
#
# geoips list product-defaults
# geoips ls pdefs
#
# geoips describe algorithm family xarray_dict_to_xarray
# geoips desc alg fam xarray_dict_to_xarray
# Out:
# Docstring: Standard GeoIPS xarray dictionary based ABI NetCDF data reader.
# Family: standard
# Interface: readers
# GeoIPS Package: geoips
# Plugin Type: module_based
# Relative Path: plugins/modules/readers/abi_netcdf.py
# Signature: (fnames, metadata_only=False, chans=None, area_def=None, self_register=False,
# 	  geolocation_cache_backend='memmap', cache_chunk_size=None, cache_data=False, cache_solar_angles=False,
# 	  resource_tracker=None, roi=None)
# Source Names:
# 	- abi
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose
#
#
# Docstring: Standard GeoIPS xarray dictionary based ABI NetCDF data reader.
# Family: standard
# Interface: readers
# GeoIPS Package: geoips
# Plugin Type: module_based
# Relative Path: plugins/modules/readers/abi_netcdf.py
# Signature: (fnames, metadata_only=False, chans=None, area_def=None, self_register=False,
# 	  geolocation_cache_backend='memmap', cache_chunk_size=None, cache_data=False, cache_solar_angles=False,
# 	  resource_tracker=None, roi=None)
# Source Names:
# 	- abi
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose
#
# ----------------
# product_defaults
# ----------------
# ╭──────────────────┬──────────────────┬──────────────────┬─────────────┬───────────────┬────────────────┬─────────────────╮
# │ GeoIPS Package   │ Interface Name   │ Interface Type   │ Family      │ Plugin Name   │ Source Names   │ Relative Path   │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ RGB-Default   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/RGB     │
# │                  │                  │                  │ r           │               │                │ -Default.ya     │
# │                  │                  │                  │             │               │                │ ml              │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ Uncorrected   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ -Channel      │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/Unc     │
# │                  │                  │                  │ r           │               │                │ orrected-Ch     │
# │                  │                  │                  │             │               │                │ annel.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_c │ windbarbs_d   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ olormapper  │ mw_high       │                │ l/product_d     │
# │                  │                  │                  │             │               │                │ efaults/geo     │
# │                  │                  │                  │             │               │                │ stationary_     │
# │                  │                  │                  │             │               │                │ dmw/windbar     │
# │                  │                  │                  │             │               │                │ bs_dmw_high     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_c │ windbarbs_d   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ olormapper  │ mw_low        │                │ l/product_d     │
# │                  │                  │                  │             │               │                │ efaults/geo     │
# │                  │                  │                  │             │               │                │ stationary_     │
# │                  │                  │                  │             │               │                │ dmw/windbar     │
# │                  │                  │                  │             │               │                │ bs_dmw_low.     │
# │                  │                  │                  │             │               │                │ yaml            │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_c │ windbarbs_d   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ olormapper  │ mw_mid        │                │ l/product_d     │
# │                  │                  │                  │             │               │                │ efaults/geo     │
# │                  │                  │                  │             │               │                │ stationary_     │
# │                  │                  │                  │             │               │                │ dmw/windbar     │
# │                  │                  │                  │             │               │                │ bs_dmw_mid.     │
# │                  │                  │                  │             │               │                │ yaml            │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_c │ windbarbs_d   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ olormapper  │ mw_multi_le   │                │ l/product_d     │
# │                  │                  │                  │             │ vel           │                │ efaults/geo     │
# │                  │                  │                  │             │               │                │ stationary_     │
# │                  │                  │                  │             │               │                │ dmw/windbar     │
# │                  │                  │                  │             │               │                │ bs_dmw_mult     │
# │                  │                  │                  │             │               │                │ i_level.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_i │ model_waves   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ nterpolator │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/mod     │
# │                  │                  │                  │ r           │               │                │ el/model_wa     │
# │                  │                  │                  │             │               │                │ ves.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_c │ model_windb   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ olormapper  │ arbs          │                │ l/product_d     │
# │                  │                  │                  │             │               │                │ efaults/mod     │
# │                  │                  │                  │             │               │                │ el/model_wi     │
# │                  │                  │                  │             │               │                │ ndbarbs.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ algorithm_i │ model_winds   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ nterpolator │ peed          │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/mod     │
# │                  │                  │                  │ r           │               │                │ el/model_wi     │
# │                  │                  │                  │             │               │                │ ndspeed.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 150H          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/150H.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 150V          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/150V.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 150VNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/150VNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 157V          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/157V.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 157VNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/157VNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 165H          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/165H.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 165HNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/165HNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 166H          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/166H.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 166HNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/166HNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 166V          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/166V.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 166VNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/166VNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183-1H        │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183-1H     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183-1HNeare   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ st            │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183-1H     │
# │                  │                  │                  │             │               │                │ Nearest.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183-3H        │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183-3H     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183-3HNeare   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ st            │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183-3H     │
# │                  │                  │                  │             │               │                │ Nearest.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183-7H        │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183-7H     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183H          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183H.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 183HNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/183HNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 190V          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/190V.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 190VNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _150/190VNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 19H           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/19H.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 19HNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/19HNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 19V           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/19V.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 19VNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/19VNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37H-Legacy    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37H-Leg     │
# │                  │                  │                  │             │               │                │ acy.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37H-LegacyN   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ earest        │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37H-Leg     │
# │                  │                  │                  │             │               │                │ acyNearest.     │
# │                  │                  │                  │             │               │                │ yaml            │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37H-Physica   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ l             │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37H-Phy     │
# │                  │                  │                  │             │               │                │ sical.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37H-Physica   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ lNearest      │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37H-Phy     │
# │                  │                  │                  │             │               │                │ sicalNeares     │
# │                  │                  │                  │             │               │                │ t.yaml          │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37H           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37H.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37HNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37HNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37V           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37V.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37VNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37VNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37pct         │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37pct.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 37pctNeares   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ t             │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/37pctNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ color37       │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/color37     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ color37Near   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ est           │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _37/color37     │
# │                  │                  │                  │             │               │                │ Nearest.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89H-Legacy    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89H-Leg     │
# │                  │                  │                  │             │               │                │ acy.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89H-LegacyN   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ earest        │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89H-Leg     │
# │                  │                  │                  │             │               │                │ acyNearest.     │
# │                  │                  │                  │             │               │                │ yaml            │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89H-Physica   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ l             │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89H-Phy     │
# │                  │                  │                  │             │               │                │ sical.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89H-Physica   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ lNearest      │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89H-Phy     │
# │                  │                  │                  │             │               │                │ sicalNeares     │
# │                  │                  │                  │             │               │                │ t.yaml          │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89H           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89H.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89HNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89HNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89HW          │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89HW.ya     │
# │                  │                  │                  │             │               │                │ ml              │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89HWNearest   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89HWNea     │
# │                  │                  │                  │             │               │                │ rest.yaml       │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89V           │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89V.yam     │
# │                  │                  │                  │             │               │                │ l               │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89VNearest    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89VNear     │
# │                  │                  │                  │             │               │                │ est.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89pct         │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89pct.y     │
# │                  │                  │                  │             │               │                │ aml             │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ 89pctNeares   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ t             │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/89pctNe     │
# │                  │                  │                  │             │               │                │ arest.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ color89       │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/color89     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ color89Near   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ est           │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/pmw     │
# │                  │                  │                  │ r           │               │                │ _89/color89     │
# │                  │                  │                  │             │               │                │ Nearest.yam     │
# ...
# │                  │ aults            │                  │ r_algorithm │ Gray          │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Infrared     │
# │                  │                  │                  │             │               │                │ -Gray.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ Infrared      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Infrared     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ Night-Vis-    │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ GeoIPS1       │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Night-       │
# │                  │                  │                  │             │               │                │ Vis-GeoIPS1     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ Night-Vis     │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Night-       │
# │                  │                  │                  │             │               │                │ Vis.yaml        │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ Visible       │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Visible.     │
# │                  │                  │                  │             │               │                │ yaml            │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ WV-Lower      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/WV-          │
# │                  │                  │                  │             │               │                │ Lower.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ WV-Upper      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/WV-          │
# │                  │                  │                  │             │               │                │ Upper.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ WV            │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/WV.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ product_def      │ yaml_based       │ interpolato │ nasa_dust_r   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │ gb            │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/nasa_dus     │
# │                  │                  │                  │             │               │                │ t_rgb.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ data_fusion      │ product_def      │ yaml_based       │ xarray_dict │ Layered-      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ _to_output_ │ Winds-        │                │ l/product_d     │
# │                  │                  │                  │ format      │ Horizontal-   │                │ efaults/Lay     │
# │                  │                  │                  │             │ Adjust        │                │ ered-Winds-     │
# │                  │                  │                  │             │               │                │ Horizontal-     │
# │                  │                  │                  │             │               │                │ Adjust.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ data_fusion      │ product_def      │ yaml_based       │ xarray_dict │ Layered-      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ _to_output_ │ Winds-        │                │ l/product_d     │
# │                  │                  │                  │ format      │ Horizontal-   │                │ efaults/Lay     │
# │                  │                  │                  │             │ and-          │                │ ered-Winds-     │
# │                  │                  │                  │             │ Vertical      │                │ Horizontal-     │
# │                  │                  │                  │             │               │                │ and-Vertica     │
# │                  │                  │                  │             │               │                │ l.yaml          │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ data_fusion      │ product_def      │ yaml_based       │ xarray_dict │ Layered-      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ _to_output_ │ Winds-        │                │ l/product_d     │
# │                  │                  │                  │ format      │ Vertical-     │                │ efaults/Lay     │
# │                  │                  │                  │             │ Adjust        │                │ ered-Winds-     │
# │                  │                  │                  │             │               │                │ Vertical-       │
# │                  │                  │                  │             │               │                │ Adjust.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ data_fusion      │ product_def      │ yaml_based       │ xarray_dict │ Layered-      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ _to_output_ │ Winds-        │                │ l/product_d     │
# │                  │                  │                  │ format      │ Vertical-     │                │ efaults/Lay     │
# │                  │                  │                  │             │ Default       │                │ ered-Winds-     │
# │                  │                  │                  │             │               │                │ Vertical-De     │
# │                  │                  │                  │             │               │                │ fault.yaml      │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geocolor         │ product_def      │ yaml_based       │ interpolato │ GeoColor      │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/GeoColor     │
# │                  │                  │                  │             │               │                │ .yaml           │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ my_package       │ product_def      │ yaml_based       │ interpolato │ 89-PCT-Test   │ N/A            │ plugins/yam     │
# │                  │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/89_     │
# │                  │                  │                  │ r           │               │                │ PCT_Test.ya     │
# │                  │                  │                  │             │               │                │ ml              │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ product_def      │ yaml_based       │ interpolato │ CLAVR-x-      │ N/A            │ plugins/yam     │
# │ rx               │ aults            │                  │ r_algorithm │ Base          │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/CLA     │
# │                  │                  │                  │ r           │               │                │ VR-x-           │
# │                  │                  │                  │             │               │                │ Base.yaml       │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ product_def      │ yaml_based       │ interpolato │ Cloud-        │ N/A            │ plugins/yam     │
# │ rx               │ aults            │                  │ r_algorithm │ Height        │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/Clo     │
# │                  │                  │                  │ r           │               │                │ ud-             │
# │                  │                  │                  │             │               │                │ Height.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ product_def      │ yaml_based       │ interpolato │ Temp          │ N/A            │ plugins/yam     │
# │ rx               │ aults            │                  │ r_algorithm │               │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/Tem     │
# │                  │                  │                  │ r           │               │                │ p.yaml          │
# ├──────────────────┼──────────────────┼──────────────────┼─────────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_plug      │ product_def      │ yaml_based       │ interpolato │ Infrared-     │ N/A            │ plugins/yam     │
# │ in_example       │ aults            │                  │ r_algorithm │ Test          │                │ l/product_d     │
# │                  │                  │                  │ _colormappe │               │                │ efaults/vis     │
# │                  │                  │                  │ r           │               │                │ ir/Infrared     │
# │                  │                  │                  │             │               │                │ -Test.yaml      │
# ╰──────────────────┴──────────────────┴──────────────────┴─────────────┴───────────────┴────────────────┴─────────────────╯
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose
#
#
# Docstring: Not Implemented.
# Family Name: xarray_dict_to_xarray
# Family Path: /local/home/evan/geoips/geoips_packages/geoips/geoips/interfaces/module_based/algorithms.py
# Interface Name: algorithms
# Interface Type: module_based
# Required Args / Schema:
# 	- xarray_dict
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose
#
#
# Docstring: Not Implemented.
# Family Name: xarray_dict_to_xarray
# Family Path: /local/home/evan/geoips/geoips_packages/geoips/geoips/interfaces/module_based/algorithms.py
# Interface Name: algorithms
# Interface Type: module_based
# Required Args / Schema:
# 	- xarray_dict
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Ensure your package is installed correctly

# %% [markdown]
# Use the CLI to check whether your package is installed correctly.
#
# If you just have **geoips** and **geoips_clavrx** installed, you should see two rows that correspond to those packages. If any additional GeoIPS packages are installed, you should see those as well.
#
# General Syntax:
# ```
# geoips list packages
# ```

# %%
# %%bash
#
# geoips list packages
# Out:
# ---------------
# GeoIPS Packages
# ---------------
# ╭───────────────────────┬─────────────────────┬─────────────────────┬────────────────────╮
# │ GeoIPS Package        │ Docstring           │ Package Path        │ Version Number     │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ ancildat              │ Fortran utilities   │ /local/home/evan/ge │ 1.15.1             │
# │                       │ to access GeoIPS    │ oips/geoips_package │                    │
# │                       │ ancillary datasets. │ s/ancildat          │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ data_fusion           │ The GeoIPS          │ /local/home/evan/ge │ 1.16.1             │
# │                       │ |unireg|            │ oips/geoips_package │                    │
# │                       │ data_fusion Package │ s/data_fusion       │                    │
# │                       │ provides a Python 3 │                     │                    │
# │                       │ plugin to GeoIPS.   │                     │                    │
# │                       │ The data_fusion     │                     │                    │
# │                       │ plugin provides the │                     │                    │
# │                       │ capability for      │                     │                    │
# │                       │ including an        │                     │                    │
# │                       │ arbitrary number of │                     │                    │
# │                       │ data types within a │                     │                    │
# │                       │ single product or   │                     │                    │
# │                       │ algorithm.  ..      │                     │                    │
# │                       │ |unireg|            │                     │                    │
# │                       │ unicode:: U+000AE   │                     │                    │
# │                       │ .. REGISTERED SIGN  │                     │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ fortran_utils         │ Fortran utilities.  │ /local/home/evan/ge │ 1.12.1             │
# │                       │                     │ oips/geoips_package │                    │
# │                       │                     │ s/fortran_utils     │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ geocolor              │ GeoColor GeoIPS     │ /local/home/evan/ge │ 1.15.2.post19.dev0 │
# │                       │ plugin.             │ oips/geoips_package │                    │
# │                       │                     │ s/geocolor          │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ geoips                │ The Geolocated      │ /local/home/evan/ge │ 1.16.2.post20.dev0 │
# │                       │ Information         │ oips/geoips_package │                    │
# │                       │ Processing System   │ s/geoips            │                    │
# │                       │ (GeoIPS).  GeoIPS   │                     │                    │
# │                       │ |unireg| Base       │                     │                    │
# │                       │ Package ----------- │                     │                    │
# │                       │ -----------------   │                     │                    │
# │                       │ The GeoIPS Base     │                     │                    │
# │                       │ Package provides a  │                     │                    │
# │                       │ Python 3 based      │                     │                    │
# │                       │ architecture        │                     │                    │
# │                       │ supporting a wide   │                     │                    │
# │                       │ variety of          │                     │                    │
# │                       │ satellite and       │                     │                    │
# │                       │ weather data        │                     │                    │
# │                       │ processing. The     │                     │                    │
# │                       │ modular nature of   │                     │                    │
# │                       │ the GeoIPS base     │                     │                    │
# │                       │ infrastructure also │                     │                    │
# │                       │ allows plug-and-    │                     │                    │
# │                       │ play capability for │                     │                    │
# │                       │ user-specified      │                     │                    │
# │                       │ custom              │                     │                    │
# │                       │ functionality.      │                     │                    │
# │                       │ Homepage: https://g │                     │                    │
# │                       │ ithub.com/NRLMMD-   │                     │                    │
# │                       │ GEOIPS/geoips  ..   │                     │                    │
# │                       │ |unireg|            │                     │                    │
# │                       │ unicode:: U+000AE   │                     │                    │
# │                       │ .. REGISTERED SIGN  │                     │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ geoips_clavrx         │ GeoIPS CLAVR-x      │ /local/home/evan/ge │ 1.16.1             │
# │                       │ plugin.             │ oips/geoips_package │                    │
# │                       │                     │ s/geoips_clavrx     │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ geoips_plugin_example │ Repository          │ /local/home/evan/ge │ 1.14.1.post2.dev0  │
# │                       │ containing various  │ oips/geoips_package │                    │
# │                       │ GeoIPS plugin       │ s/geoips_plugin_exa │                    │
# │                       │ examples.           │ mple                │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ my_package            │ Template repository │ /local/home/evan/ge │ 1.16.1             │
# │                       │ demonstrating a     │ oips/geoips_package │                    │
# │                       │ basic GeoIPS plugin │ s/template_basic_pl │                    │
# │                       │ example.            │ ugin                │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ rayleigh              │ Fortran utilities   │ /local/home/evan/ge │ 1.15.1             │
# │                       │ to access GeoIPS    │ oips/geoips_package │                    │
# │                       │ ancillary datasets. │ s/rayleigh          │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ recenter_tc           │ Recenter tropical   │ /local/home/evan/ge │ 1.16.1             │
# │                       │ cyclone imagery.    │ oips/geoips_package │                    │
# │                       │ The recenter_tc     │ s/recenter_tc       │                    │
# │                       │ package provides    │                     │                    │
# │                       │ the capability for  │                     │                    │
# │                       │ identifying the     │                     │                    │
# │                       │ most accurate storm │                     │                    │
# │                       │ center based on     │                     │                    │
# │                       │ best track and      │                     │                    │
# │                       │ storm forecast      │                     │                    │
# │                       │ information, as     │                     │                    │
# │                       │ well as the data    │                     │                    │
# │                       │ itself.  Two        │                     │                    │
# │                       │ separate packages   │                     │                    │
# │                       │ are used in         │                     │                    │
# │                       │ determining the     │                     │                    │
# │                       │ most accurate storm │                     │                    │
# │                       │ center:  akima86    │                     │                    │
# │                       │ fortran based       │                     │                    │
# │                       │ interpolation H.    │                     │                    │
# │                       │ Akima 1986, Python  │                     │                    │
# │                       │ adaptation D.       │                     │                    │
# │                       │ Ryglicki 2020  This │                     │                    │
# │                       │ takes in all        │                     │                    │
# │                       │ current best track  │                     │                    │
# │                       │ information,        │                     │                    │
# │                       │ forecasted storm    │                     │                    │
# │                       │ locations, as well  │                     │                    │
# │                       │ as the actual time  │                     │                    │
# │                       │ of the data file    │                     │                    │
# │                       │ itself. The         │                     │                    │
# │                       │ 6-hourly storm      │                     │                    │
# │                       │ location            │                     │                    │
# │                       │ information is      │                     │                    │
# │                       │ interpolated to the │                     │                    │
# │                       │ actual data time.   │                     │                    │
# │                       │ Automated           │                     │                    │
# │                       │ Rotational Center   │                     │                    │
# │                       │ Hurricane Eye       │                     │                    │
# │                       │ Retrieval (ARCHER)  │                     │                    │
# │                       │ T. Wimmers          │                     │                    │
# │                       │ University of       │                     │                    │
# │                       │ Wisconsin           │                     │                    │
# │                       │ Cooperative         │                     │                    │
# │                       │ Institute for       │                     │                    │
# │                       │ Meteorological      │                     │                    │
# │                       │ Satellite Studies   │                     │                    │
# │                       │ Using the akima86   │                     │                    │
# │                       │ interpolated center │                     │                    │
# │                       │ as a starting       │                     │                    │
# │                       │ point, ARCHER       │                     │                    │
# │                       │ identifies the      │                     │                    │
# │                       │ actual storm center │                     │                    │
# │                       │ from the data       │                     │                    │
# │                       │ itself. ARCHER      │                     │                    │
# │                       │ operates on passive │                     │                    │
# │                       │ microwave, visible, │                     │                    │
# │                       │ and infrared data   │                     │                    │
# │                       │ types  recenter_tc  │                     │                    │
# │                       │ wrapper             │                     │                    │
# │                       │ "area_def_adjuster" │                     │                    │
# │                       │ akima86 and archer  │                     │                    │
# │                       │ are called via the  │                     │                    │
# │                       │ recenter_tc         │                     │                    │
# │                       │ "area_def_adjuster" │                     │                    │
# │                       │ plugin. Currently,  │                     │                    │
# │                       │ the recenter_tc     │                     │                    │
# │                       │ area_def_adjuster   │                     │                    │
# │                       │ is accessed by      │                     │                    │
# │                       │ specifying the "--  │                     │                    │
# │                       │ adjust_area_def     │                     │                    │
# │                       │ recenter_tc"        │                     │                    │
# │                       │ command line        │                     │                    │
# │                       │ argument, and the   │                     │                    │
# │                       │ procflows handle    │                     │                    │
# │                       │ calling akima86,    │                     │                    │
# │                       │ calling archer,     │                     │                    │
# │                       │ adjusting the area  │                     │                    │
# │                       │ definition          │                     │                    │
# │                       │ appropriately, and  │                     │                    │
# │                       │ generating related  │                     │                    │
# │                       │ ARCHER f-deck and   │                     │                    │
# │                       │ image outputs.      │                     │                    │
# │                       │ ARCHER output       │                     │                    │
# │                       │ currently defaults  │                     │                    │
# │                       │ to $GEOIPS_OUTDIRS/ │                     │                    │
# │                       │ preprocessed/archer │                     │                    │
# │                       │ , and filename      │                     │                    │
# │                       │ formats and         │                     │                    │
# │                       │ locations can be    │                     │                    │
# │                       │ adjusted via        │                     │                    │
# │                       │ adjustments to      │                     │                    │
# │                       │ filename_format     │                     │                    │
# │                       │ plugins. Future     │                     │                    │
# │                       │ updates to the      │                     │                    │
# │                       │ recenter_tc plugin  │                     │                    │
# │                       │ package will        │                     │                    │
# │                       │ provide easier      │                     │                    │
# │                       │ access to adjusting │                     │                    │
# │                       │ the ARCHER output - │                     │                    │
# │                       │ it is currently     │                     │                    │
# │                       │ controlled via      │                     │                    │
# │                       │ environment         │                     │                    │
# │                       │ variables           │                     │                    │
# │                       │ specifying which    │                     │                    │
# │                       │ filename format     │                     │                    │
# │                       │ plugins to use for  │                     │                    │
# │                       │ both image and fix  │                     │                    │
# │                       │ outputs.  The       │                     │                    │
# │                       │ default filename    │                     │                    │
# │                       │ format plugins      │                     │                    │
# │                       │ currently in use    │                     │                    │
# │                       │ within recenter_tc  │                     │                    │
# │                       │ are:  export ARCHER │                     │                    │
# │                       │ _IMAGE_FILENAME_FOR │                     │                    │
# │                       │ MAT=archer_image    │                     │                    │
# │                       │ Located in recenter │                     │                    │
# │                       │ _tc/interface_modul │                     │                    │
# │                       │ es/filename_formats │                     │                    │
# │                       │ /archer_image.py    │                     │                    │
# │                       │ export ARCHER_FIX_F │                     │                    │
# │                       │ ILENAME_FORMAT=arch │                     │                    │
# │                       │ er_fix Located in r │                     │                    │
# │                       │ ecenter_tc/interfac │                     │                    │
# │                       │ e_modules/filename_ │                     │                    │
# │                       │ formats/archer_fix. │                     │                    │
# │                       │ py                  │                     │                    │
# ├───────────────────────┼─────────────────────┼─────────────────────┼────────────────────┤
# │ synth_green           │ Fortran utilities   │ /local/home/evan/ge │ 1.12.1             │
# │                       │ for creating a      │ oips/geoips_package │                    │
# │                       │ synthetic green     │ s/synth_green       │                    │
# │                       │ channel.            │                     │                    │
# ╰───────────────────────┴─────────────────────┴─────────────────────┴────────────────────╯
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Command: geoips list

# %% [markdown]
# List all reader plugins from GeoIPS & installed plugin packages.
#
# If just **geoips** and **geoips_clavrx** are installed, you should see reader plugins contained in both of those packages.
#
# General Syntax:
# ```
# geoips list <interface_name>
# ```

# %%
# %%bash
#
# geoips list readers
# Out:
# -------
# readers
# -------
# ╭──────────────────┬──────────────────┬──────────────────┬──────────┬───────────────┬────────────────┬─────────────────╮
# │ GeoIPS Package   │ Interface Name   │ Interface Type   │ Family   │ Plugin Name   │ Source Names   │ Relative Path   │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ imerg_hdf5    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/imerg_hdf     │
# │                  │                  │                  │          │               │                │ 5.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ scat_noaa_w   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ inds_netcdf   │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/scat_noaa     │
# │                  │                  │                  │          │               │                │ _winds_netc     │
# │                  │                  │                  │          │               │                │ df.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ssmi_binary   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ssmi_bina     │
# │                  │                  │                  │          │               │                │ ry.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ abi_netcdf    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/abi_netcd     │
# │                  │                  │                  │          │               │                │ f.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ amsr2_remss   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ _winds_netc   │                │ ules/reader     │
# │                  │                  │                  │          │ df            │                │ s/amsr2_rem     │
# │                  │                  │                  │          │               │                │ ss_winds_ne     │
# │                  │                  │                  │          │               │                │ tcdf.py         │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ windsat_rem   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ ss_winds_ne   │                │ ules/reader     │
# │                  │                  │                  │          │ tcdf          │                │ s/windsat_r     │
# │                  │                  │                  │          │               │                │ emss_winds_     │
# │                  │                  │                  │          │               │                │ netcdf.py       │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ fci_netcdf    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/fci_netcd     │
# │                  │                  │                  │          │               │                │ f.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ windsat_idr   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ 37_binary     │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/windsat_i     │
# │                  │                  │                  │          │               │                │ dr37_binary     │
# │                  │                  │                  │          │               │                │ .py             │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ amsr2_netcd   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ f             │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/amsr2_net     │
# │                  │                  │                  │          │               │                │ cdf.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ aws_netcdf    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/aws_netcd     │
# │                  │                  │                  │          │               │                │ f.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ssmis_binar   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ y             │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ssmis_bin     │
# │                  │                  │                  │          │               │                │ ary.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ atms_hdf5     │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/atms_hdf5     │
# │                  │                  │                  │          │               │                │ .py             │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ modis_hdf4    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/modis_hdf     │
# │                  │                  │                  │          │               │                │ 4.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ abi_l2_netc   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ df            │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/abi_l2_ne     │
# │                  │                  │                  │          │               │                │ tcdf.py         │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ seviri_hrit   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/seviri_hr     │
# │                  │                  │                  │          │               │                │ it.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ wfabba_asci   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ i             │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/wfabba_as     │
# │                  │                  │                  │          │               │                │ cii.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ viirs_l2_ne   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ tcdf          │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/viirs_l2_     │
# │                  │                  │                  │          │               │                │ netcdf.py       │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ geoips_netc   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ df            │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/geoips_ne     │
# │                  │                  │                  │          │               │                │ tcdf.py         │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ amsua_mhs_m   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ irs           │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/amsua_mhs     │
# │                  │                  │                  │          │               │                │ _mirs.py        │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ cygnss_netc   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ df            │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/cygnss_ne     │
# │                  │                  │                  │          │               │                │ tcdf.py         │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ viirs_sdr_h   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ df5           │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/viirs_sdr     │
# │                  │                  │                  │          │               │                │ _hdf5.py        │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ sar_winds_n   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ etcdf         │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/sar_winds     │
# │                  │                  │                  │          │               │                │ _netcdf.py      │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ascat_uhr_n   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ etcdf         │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ascat_uhr     │
# │                  │                  │                  │          │               │                │ _netcdf.py      │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ewsg_netcdf   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ewsg_netc     │
# │                  │                  │                  │          │               │                │ df.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ amsub_hdf     │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/amsub_hdf     │
# │                  │                  │                  │          │               │                │ .py             │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ smos_winds_   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ netcdf        │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/smos_wind     │
# │                  │                  │                  │          │               │                │ s_netcdf.py     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ mimic_netcd   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ f             │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/mimic_net     │
# │                  │                  │                  │          │               │                │ cdf.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ viirs_netcd   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ f             │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/viirs_net     │
# │                  │                  │                  │          │               │                │ cdf.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ami_netcdf    │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ami_netcd     │
# │                  │                  │                  │          │               │                │ f.py            │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ smap_remss_   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ winds_netcd   │                │ ules/reader     │
# │                  │                  │                  │          │ f             │                │ s/smap_rems     │
# │                  │                  │                  │          │               │                │ s_winds_net     │
# │                  │                  │                  │          │               │                │ cdf.py          │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ saphir_hdf5   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/saphir_hd     │
# │                  │                  │                  │          │               │                │ f5.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ gmi_hdf5      │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/gmi_hdf5.     │
# │                  │                  │                  │          │               │                │ py              │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ scat_knmi_w   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ inds_netcdf   │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/scat_knmi     │
# │                  │                  │                  │          │               │                │ _winds_netc     │
# │                  │                  │                  │          │               │                │ df.py           │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ ahi_hsd       │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/ahi_hsd.p     │
# │                  │                  │                  │          │               │                │ y               │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ sfc_winds_t   │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │ ext           │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/sfc_winds     │
# │                  │                  │                  │          │               │                │ _text.py        │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips           │ readers          │ module_base      │ standard │ gfs_grib      │ N/A            │ plugins/mod     │
# │                  │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/gfs_grib.     │
# │                  │                  │                  │          │               │                │ py              │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ readers          │ module_base      │ standard │ clavrx_netc   │ N/A            │ plugins/mod     │
# │ rx               │                  │ d                │          │ df4           │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/clavrx_ne     │
# │                  │                  │                  │          │               │                │ tcdf4.py        │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ readers          │ module_base      │ standard │ clavrx_hdf4   │ N/A            │ plugins/mod     │
# │ rx               │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/clavrx_hd     │
# │                  │                  │                  │          │               │                │ f4.py           │
# ╰──────────────────┴──────────────────┴──────────────────┴──────────┴───────────────┴────────────────┴─────────────────╯
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## List plugins from a specific plugin package

# %% [markdown]
# List available plugins of a particular type from a specific plugin package.
#
# General Syntax:
# ```
# geoips list <interface_name> -p <package_name>
# ```

# %%
# %%bash
#
# # if geoips_clavrx is installed, you can run the command below. Same goes for any other geoips-based package
# geoips list readers -p geoips_clavrx
# # Otherwise, for clarity's sake, you can list reader plugins from a specific package via
# # geoips list readers -p <installed_package_name>
# Out:
# -------
# readers
# -------
# ╭──────────────────┬──────────────────┬──────────────────┬──────────┬───────────────┬────────────────┬─────────────────╮
# │ GeoIPS Package   │ Interface Name   │ Interface Type   │ Family   │ Plugin Name   │ Source Names   │ Relative Path   │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ readers          │ module_base      │ standard │ clavrx_netc   │ N/A            │ plugins/mod     │
# │ rx               │                  │ d                │          │ df4           │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/clavrx_ne     │
# │                  │                  │                  │          │               │                │ tcdf4.py        │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ readers          │ module_base      │ standard │ clavrx_hdf4   │ N/A            │ plugins/mod     │
# │ rx               │                  │ d                │          │               │                │ ules/reader     │
# │                  │                  │                  │          │               │                │ s/clavrx_hd     │
# │                  │                  │                  │          │               │                │ f4.py           │
# ╰──────────────────┴──────────────────┴──────────────────┴──────────┴───────────────┴────────────────┴─────────────────╯
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Command: geoips describe

# %% [markdown]
# Display additional information about a particular plugin.
#
# General Syntax:
# ```
# geoips describe <interface_name> <plugin_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips describe reader clavrx_hdf4
# # Otherwise, run a command similar to what is shown below
# # geoips describe reader <name_of_reader_in_installed_package>
# Out:
# Docstring: 'CLAVR-x hdf4 cloud property data reader.
#
#   S.Yang:  1/19/2023 G.Uttmark:  11/05/2024'
# Family: standard
# Interface: readers
# GeoIPS Package: geoips_clavrx
# Plugin Type: module_based
# Relative Path: plugins/modules/readers/clavrx_hdf4.py
# Signature: (fnames, metadata_only=False, chans=None, area_def=None, self_register=False)
# Source Names:
# 	- Unspecified
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Command: geoips list products

# %% [markdown]
# List the products that GeoIPS can produce using a particular plugin package.
#
# General Syntax:
# ```
# geoips list <interface_name> -p <package_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips list products -p geoips_clavrx
# # Otherwise, run a command similar to what is shown below
# # geoips list products -p <installed_package_name>
# Out:
# --------
# products
# --------
# ╭──────────────────┬──────────────────┬──────────────────┬──────────┬───────────────┬────────────────┬─────────────────╮
# │ GeoIPS Package   │ Interface Name   │ Interface Type   │ Family   │ Plugin Name   │ Source Names   │ Relative Path   │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-        │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Fraction      │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Type    │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │               │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Mask    │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │               │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Base-   │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Height        │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Top-    │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Height        │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-        │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Optical-      │                │ l/products/     │
# │                  │                  │                  │          │ Depth         │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Phase   │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │               │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Cloud-Temp-   │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ ACHA          │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Temp-3p75     │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │               │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Temp-11p0     │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │               │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Effective-    │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Radius        │                │ l/products/     │
# │                  │                  │                  │          │               │                │ clavrx.yaml     │
# ├──────────────────┼──────────────────┼──────────────────┼──────────┼───────────────┼────────────────┼─────────────────┤
# │ geoips_clav      │ products         │ yaml_based       │ N/A      │ Absdiff-      │ ['clavrx']     │ plugins/yam     │
# │ rx               │                  │                  │          │ Cloud-Top-    │                │ l/products/     │
# │                  │                  │                  │          │ Height        │                │ clavrx.yaml     │
# ╰──────────────────┴──────────────────┴──────────────────┴──────────┴───────────────┴────────────────┴─────────────────╯
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Command: geoips describe product

# %% [markdown]
# Display additional information about a particular product plugin.
#
# Running this command describes ‘Cloud-Fraction’, including:
# - What type of plugin it is
# - Where it comes from
# - What source supports this product
#
# General Syntax:
# ```
# geoips describe <interface_name> <source_name>.<plugin_name>
# ```

# %%
# %%bash
#
# # Again, only run if the geoips_clavrx package is installed
# geoips describe product clavrx.Cloud-Fraction
# # Otherwise, run a command similar to what is shown below
# # geoips describe product <name_of_product_in_installed_package>
# Out:
# Docstring: GeoIPS CLAVR-x Cloud Fraction product.
# Family: null
# Interface: products
# GeoIPS Package: geoips_clavrx
# Plugin Type: yaml_based
# Product Defaults: CLAVR-x-Base
# Relative Path: plugins/yaml/products/clavrx.yaml
# Source Names:
# 	- clavrx
#
#
# WARNING: The GeoIPS CLI is currently under development and is subject to change.
# Until this warning is removed, do not rely on the CLI to be static.
# Please feel free to test the CLI and report any bugs or comments as an issue here:
# https://github.com/NRLMMD-GEOIPS/geoips/issues/new/choose

# %% [markdown]
# ## Command: geoips config install

# %% [markdown]
# Install GeoIPS’ test datasets.
#
# Running this command downloads and extracts test datasets from our nextcloud storage server.
# These test datasets are needed for various integration tests across GeoIPS and its plugin packages.
#
# General Syntax:
# ```
# geoips config install <test_dataset_name> <test_dataset_name2> ...
# ```
#
# To view what datasets are available for install, run:
# ```
# geoips list test-datasets
# ```

# %%
# %%bash
#
# geoips config install test_data_abi

# %% [markdown]
# ## Command: geoips run

# %% [markdown]
# GeoIPS is run by calling `geoips run`.
#
# For repeatability, this can be put into a bash script (e.g. `abi.Cloud-Fraction.imagery_clean.sh`).
#
# General Syntax:
# ```
# geoips run <procflow_name> <procflow_args>
# ```
#
# For a listing of scripts available in core GeoIPS, see [here](https://github.com/NRLMMD-GEOIPS/geoips/tree/main/tests/scripts).
#
# Note that you'll need to have the corresponding test data installed for these scripts to work.

# %%
# %%bash
#
# geoips run single_source \
# $GEOIPS_TESTDATA_DIR/test_data_abi/data/goes16_20200918_1950/*.nc \
#    --reader_name abi_netcdf \
#    --product_name Infrared \
#    --output_formatter imagery_clean \
#    --sector_list goes_east
#
# # Feel free to replace the contents of this code section with a test script that
# # native GeoIPS supports

# %% [markdown]
# ## Command: geoips test sector

# %% [markdown]
# Produce a ‘test sector image’.
#
# Running this command produces a test sector image from the ‘canada’ sector plugin.
# This is an easy method to view what geospatial domain a sector you’ve created captures.
#
# General Syntax:
# ```
# geoips test sector <sector_name>
# ```

# %%
# %%bash
#
# geoips test sector canada

# %% [markdown]
# ## Command: geoips config create/delete registries

# %% [markdown]
# Create or delete plugin registries.
#
# Running either of these commands will create or delete plugin registries.
# These files are needed for GeoIPS to be able to dynamically locate a plugin at runtime.
#
# General Syntax:
# ```
# geoips config create-registries -n <namespace> -p <package_names> -s <save_type>
# geoips config delete-registries -n <namespace> -p <package_names>
# ```
#
# Note: Registries are automatically created if a plugin is missing at runtime.
# You can disable this by adding the following line in your `.bashrc`:
# ```
# export GEOIPS_REBUILD_REGISTRIES="False"
# ```

# %%
# %%bash
#
# geoips config create-registries
# # geoips config delete-registries
